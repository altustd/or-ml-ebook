# %% [markdown]
# # Modern Operations Research with Python
#
# **Optimization • Machine Learning • Data-Driven Decision Making**
#
# This book combines classical Operations Research techniques with modern Machine Learning using Python.

# %% [markdown]
# ## Quick Start Guide

# %% [markdown]
# ### 1. Clone the repository

# %%
# Run this in your terminal
# git clone https://github.com/altustd/or-ml-ebook.git
# cd or-ml-ebook

# %% [markdown]
# ### 2. Activate the environment

# %%
# In terminal:
# or-ml-ebook-env

# %% [markdown]
# ### 3. Install dependencies

# %%
# pip install -r requirements.txt

# %% [markdown]
# ### 4. Render the book

# %%
# quarto render

# %% [markdown]
# ### 5. Open the HTML version

# %%
# open _book/index.html

# %% [markdown]
# ## Book Contents
#
# - **Chapter 1**: Introduction to Modern Operations Research with Python
# - **Chapter 2**: Linear Programming
# - **Chapter 3**: Network Optimization
# - **Chapter 4**: Integer Programming
# - **Chapter 5**: Nonlinear Optimization
# - **Chapter 6**: Stochastic Optimization
# - **Chapter 7**: Reinforcement Learning in Operations Research

# %% [markdown]
# ## How to Contribute
#
# Feel free to open issues or submit pull requests.
# All code examples are designed to be executable and reproducible.

# %% [markdown]
# ## License
#
# MIT License — see the [LICENSE](LICENSE) file for details.
#
# ---
#
# Built with [Quarto](https://quarto.org)
